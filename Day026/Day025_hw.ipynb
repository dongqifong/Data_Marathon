# %% [markdown]
# ## 作業:
# 今天學到不同統計量之間特性，
# 試著分析男生女生身高資料，
# 試著回答下面的問題:
# Q1:試著用今天所教的內容，如何描述這兩組資料的樣態?
# Q2: 請問男生和女生在平均身高上誰比較高?
# Q3:請問第二題的答案和日常生活中觀察的一致嗎? 如果不一致，你覺得原因可能為何?
# 上述問題透過  python 語法進行運算，
# 並將上述答案填寫在 (google 表單)[https://forms.gle/EDdU2Zfq8zLvDea18]
# ![](作業資料圖檔.PNG)

# %%
# library
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import math
import statistics
import seaborn as sns

# %%
#輸入資料
boys=[164, 176, 169, 169, 165, 175, 159, 151, 144, 160, 183, 165, 156, 170,
 164, 173, 165, 163, 177, 171]
girls=[169,170,162,154,183,173,169,167,170,185,162,175,168,151,181,170,182,156,159,160]
data={}
data['boy']=boys
data['girl']=girls

# %%
#Q1:試著用今天所教的內容，如何描述這兩組資料的樣態?
#暗示:  分別計算男生和女生的統計量
'''
你的答案
'''
# mean_boy=np.mean(boys)
# mean_girl=np.mean(girls)
# var_boy=np.var(boys,ddof=1)
# var_girl=np.var(girls,ddof=1)
# percentile_25_boy=np.percentile(boys, 25)
# percentile_75_boy=np.percentile(boys, 75)
# percentile_25_girl=np.percentile(girls, 25)
# percentile_75_girl=np.percentile(girls, 75)
# print('boy的平均數={},變異數={},%25百分位數={},%75百分位數={}'.format(mean_boy,var_boy,percentile_25_boy,percentile_75_boy))
# print('girl的平均數={},變異數={},%25百分位數={},%75百分位數={}'.format(mean_girl,var_girl,percentile_25_girl,percentile_75_girl))
df=pd.DataFrame(data=data)
print(df.describe())
df.hist(bins=10)
# Out:
#               boy        girl
# count   20.000000   20.000000
# mean   165.950000  168.300000
# std      9.213691    9.766215
# min    144.000000  151.000000
# 25%    162.250000  161.500000
# 50%    165.000000  169.000000
# 75%    171.500000  173.500000
# max    183.000000  185.000000
# array([[<AxesSubplot:title={'center':'boy'}>,
#         <AxesSubplot:title={'center':'girl'}>]], dtype=object)

# %%
#Q2: 請問男生和女生在平均身高上誰比較高? 
'''
你的答案
'''
print('女生的平均身高比較高')
# Out:
# 女生的平均身高比較高

# %%
#Q3:請問第二題的答案和日常生活中觀察的一致嗎? 如果不一致，你覺得原因可能為何? 
'''
你的答案
'''
print('男生和女生挑選的族群有差異，例如男生是從亞洲區域取樣，而女生是從歐洲國家取樣')
# Out:
# 男生和女生挑選的族群有差異，例如男生是從亞洲區域取樣，而女生是從歐洲國家取樣
